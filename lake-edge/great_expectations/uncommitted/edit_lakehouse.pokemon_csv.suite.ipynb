# %% [markdown]
# # Edit Your Expectation Suite
# Use this notebook to recreate and modify your expectation suite:
#
# **Expectation Suite Name**: `lakehouse.pokemon_csv.suite`

# %%
import datetime

import pandas as pd

import great_expectations as ge
import great_expectations.jupyter_ux
from great_expectations.core.batch import BatchRequest
from great_expectations.checkpoint import SimpleCheckpoint
from great_expectations.exceptions import DataContextError

context = ge.data_context.DataContext()

# Note that if you modify this batch request, you may save the new version as a .json file
#  to pass in later via the --batch-request option
batch_request = {'datasource_name': 'trino', 'data_connector_name': 'default_inferred_data_connector_name', 'data_asset_name': 'lakehouse.pokemon_csv', 'limit': 1000}


# Feel free to change the name of your suite here. Renaming this will not remove the other one.
expectation_suite_name = "lakehouse.pokemon_csv.suite"
try:
    suite = context.get_expectation_suite(expectation_suite_name=expectation_suite_name)
    print(f'Loaded ExpectationSuite "{suite.expectation_suite_name}" containing {len(suite.expectations)} expectations.')
except DataContextError:
    suite = context.create_expectation_suite(expectation_suite_name=expectation_suite_name)
    print(f'Created ExpectationSuite "{suite.expectation_suite_name}".')


validator = context.get_validator(
    batch_request=BatchRequest(**batch_request),
    expectation_suite_name=expectation_suite_name
)
column_names = [f'"{column_name}"' for column_name in validator.columns()]
print(f"Columns: {', '.join(column_names)}.")
validator.head(n_rows=5, fetch_all=False)
# Out:
# Loaded ExpectationSuite "lakehouse.pokemon_csv.suite" containing 46 expectations.
# Calculating Metrics:   0%|                                                                                                  | 0/2 [00:01<?, ?it/s]
# 2022-06-17T22:29:59+0000 - WARNING - Exceptions
# {('table.column_types', 'batch_id=bb18c4e94563cc7f710d3319f16987d6', 'include_nested=True'): {'metric_configuration': {
#   "metric_name": "table.column_types",
#   "metric_domain_kwargs": {
#     "batch_id": "bb18c4e94563cc7f710d3319f16987d6"
#   },
#   "metric_domain_kwargs_id": "batch_id=bb18c4e94563cc7f710d3319f16987d6",
#   "metric_value_kwargs": {
#     "include_nested": true
#   },
#   "metric_value_kwargs_id": "include_nested=True",
#   "id": [
#     "table.column_types",
#     "batch_id=bb18c4e94563cc7f710d3319f16987d6",
#     "include_nested=True"
#   ]
# }, 'num_failures': 3, 'exception_info': {{'exception_traceback': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.9/site-packages/great_expectations/execution_engine/execution_engine.py", line 386, in resolve_metrics\n    resolved_metrics[metric_to_resolve.id] = metric_fn(\n  File "/usr/local/lib/python3.9/site-packages/great_expectations/expectations/metrics/metric_provider.py", line 34, in inner_func\n    return metric_fn(*args, **kwargs)\n  File "/usr/local/lib/python3.9/site-packages/great_expectations/expectations/metrics/table_metrics/table_column_types.py", line 71, in _sqlalchemy\n    return _get_sqlalchemy_column_metadata(execution_engine.engine, batch_data)\n  File "/usr/local/lib/python3.9/site-packages/great_expectations/expectations/metrics/table_metrics/table_column_types.py", line 100, in _get_sqlalchemy_column_metadata\n    return get_sqlalchemy_column_metadata(\n  File "/usr/local/lib/python3.9/site-packages/great_expectations/expectations/metrics/util.py", line 337, in get_sqlalchemy_column_metadata\n    columns = inspector.get_columns(\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py", line 497, in get_columns\n    col_defs = self.dialect.get_columns(\n  File "/usr/local/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 104, in get_columns\n    return self._get_columns(connection, table_name, schema, **kw)\n  File "/usr/local/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py", line 121, in _get_columns\n    res = connection.execute(sql.text(query), schema=schema, table=table_name)\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1306, in execute\n    return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/sql/elements.py", line 325, in _execute_on_connection\n    return connection._execute_clauseelement(\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1498, in _execute_clauseelement\n    ret = self._execute_context(\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1862, in _execute_context\n    self._handle_dbapi_exception(\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2047, in _handle_dbapi_exception\n    util.raise_(exc_info[1], with_traceback=exc_info[2])\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 208, in raise_\n    raise exception\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1835, in _execute_context\n    result = context._setup_result_proxy()\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 1447, in _setup_result_proxy\n    result = self._setup_dml_or_text_result()\n  File "/usr/local/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 1529, in _setup_dml_or_text_result\n    strategy.alternate_cursor_description or self.cursor.description\n  File "/usr/local/lib/python3.9/site-packages/trino/dbapi.py", line 257, in description\n    if self._query.columns is None:\n  File "/usr/local/lib/python3.9/site-packages/trino/client.py", line 622, in columns\n    self._result._rows += self.fetch()\n  File "/usr/local/lib/python3.9/site-packages/trino/client.py", line 677, in fetch\n    status = self._request.process(response)\n  File "/usr/local/lib/python3.9/site-packages/trino/client.py", line 440, in process\n    raise self._process_error(response["error"], response.get("id"))\n  File "/usr/local/lib/python3.9/site-packages/trino/client.py", line 412, in _process_error\n    raise exceptions.TrinoExternalError(error, query_id)\ntrino.exceptions.TrinoExternalError: TrinoExternalError(type=EXTERNAL, name=UNSUPPORTED_TABLE_TYPE, message="Not an Iceberg table: lakehouse.pokemon_csv", query_id=20220617_222959_00115_s8x4h)\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  Fil ...
# occurred while resolving metrics.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [2], in <cell line: 32>()
#      25     print(f'Created ExpectationSuite "{suite.expectation_suite_name}".')
#      28 validator = context.get_validator(
#      29     batch_request=BatchRequest(**batch_request),
#      30     expectation_suite_name=expectation_suite_name
#      31 )
# ---> 32 column_names = [f'"{column_name}"' for column_name in validator.columns()]
#      33 print(f"Columns: {', '.join(column_names)}.")
#      34 validator.head(n_rows=5, fetch_all=False)
#
# File /usr/local/lib/python3.9/site-packages/great_expectations/validator/validator.py:2126, in Validator.columns(self, domain_kwargs)
#    2121 if domain_kwargs is None:
#    2122     domain_kwargs = {
#    2123         "batch_id": self.execution_engine.active_batch_data_id,
#    2124     }
# -> 2126 columns: List[str] = self.get_metric(
#    2127     metric=MetricConfiguration(
#    2128         metric_name="table.columns",
#    2129         metric_domain_kwargs=domain_kwargs,
#    2130     )
#    2131 )
#    2133 return columns
#
# File /usr/local/lib/python3.9/site-packages/great_expectations/validator/validator.py:891, in Validator.get_metric(self, metric)
#     889 def get_metric(self, metric: MetricConfiguration) -> Any:
#     890     """return the value of the requested metric."""
# --> 891     return self.get_metrics(metrics={metric.metric_name: metric})[
#     892         metric.metric_name
#     893     ]
#
# File /usr/local/lib/python3.9/site-packages/great_expectations/validator/validator.py:856, in Validator.get_metrics(self, metrics)
#     848 """
#     849 metrics: Dictionary of desired metrics to be resolved, with metric_name as key and MetricConfiguration as value.
#     850 Return Dictionary with requested metrics resolved, with metric_name as key and computed metric as value.
#     851 """
#     852 resolved_metrics: Dict[Tuple[str, str, str], Any] = self.compute_metrics(
#     853     metric_configurations=list(metrics.values())
#     854 )
# --> 856 return {
#     857     metric_configuration.metric_name: resolved_metrics[metric_configuration.id]
#     858     for metric_configuration in metrics.values()
#     859 }
#
# File /usr/local/lib/python3.9/site-packages/great_expectations/validator/validator.py:857, in <dictcomp>(.0)
#     848 """
#     849 metrics: Dictionary of desired metrics to be resolved, with metric_name as key and MetricConfiguration as value.
#     850 Return Dictionary with requested metrics resolved, with metric_name as key and computed metric as value.
#     851 """
#     852 resolved_metrics: Dict[Tuple[str, str, str], Any] = self.compute_metrics(
#     853     metric_configurations=list(metrics.values())
#     854 )
#     856 return {
# --> 857     metric_configuration.metric_name: resolved_metrics[metric_configuration.id]
#     858     for metric_configuration in metrics.values()
#     859 }
#
# KeyError: ('table.columns', 'batch_id=bb18c4e94563cc7f710d3319f16987d6', ())

# %% [markdown]
# ## Create & Edit Expectations
#
#
# Add expectations by calling specific expectation methods on the `validator` object. They all begin with `.expect_` which makes autocompleting easy using tab.
#
# Because you selected interactive mode, you are now creating or editing an Expectation Suite with validator feedback from the sample batch of data that you specified (see `batch_request`).
#
# Note that if you select manual mode you may still create or edit an Expectation Suite directly, without feedback from the `validator`. See our documentation for more info and examples: [How to create a new Expectation Suite without a sample batch](https://docs.greatexpectations.io/docs/guides/expectations/how_to_create_and_edit_expectations_based_on_domain_knowledge_without_inspecting_data_directly).
#
#
#
# You can see all the available expectations in the **[expectation gallery](https://greatexpectations.io/expectations)**.

# %% [markdown]
# ### Table Expectation(s)

# %%
validator.expect_table_row_count_to_equal(value=1032)

# %%
validator.expect_table_columns_to_match_ordered_list(column_list=['number', 'name', 'type 1', 'type 2', 'abilities', 'hp', 'att', 'def', 'spa', 'spd', 'spe', 'bst', 'mean', 'standard deviation', 'generation', 'experience type', 'experience to level 100', 'final evolution', 'catch rate', 'legendary', 'mega evolution', 'alolan form', 'galarian form', 'against normal', 'against fire', 'against water', 'against electric', 'against grass', 'against ice', 'against fighting', 'against poison', 'against ground', 'against flying', 'against psychic', 'against bug', 'against rock', 'against ghost', 'against dragon', 'against dark', 'against steel', 'against fairy', 'height', 'weight', 'bmi'])

# %% [markdown]
# ### Column Expectation(s)

# %% [markdown]
# #### `number`

# %%
validator.expect_column_values_to_be_of_type(column='number', type_='VARCHAR')

# %% [markdown]
# #### `name`

# %%
validator.expect_column_values_to_be_of_type(column='name', type_='VARCHAR')

# %% [markdown]
# #### `type 1`

# %%
validator.expect_column_values_to_be_of_type(column='type 1', type_='VARCHAR')

# %% [markdown]
# #### `type 2`

# %%
validator.expect_column_values_to_be_of_type(column='type 2', type_='VARCHAR')

# %% [markdown]
# #### `abilities`

# %%
validator.expect_column_values_to_be_of_type(column='abilities', type_='VARCHAR')

# %% [markdown]
# #### `hp`

# %%
validator.expect_column_values_to_be_of_type(column='hp', type_='VARCHAR')

# %% [markdown]
# #### `att`

# %%
validator.expect_column_values_to_be_of_type(column='att', type_='VARCHAR')

# %% [markdown]
# #### `def`

# %%
validator.expect_column_values_to_be_of_type(column='def', type_='VARCHAR')

# %% [markdown]
# #### `spa`

# %%
validator.expect_column_values_to_be_of_type(column='spa', type_='VARCHAR')

# %% [markdown]
# #### `spd`

# %%
validator.expect_column_values_to_be_of_type(column='spd', type_='VARCHAR')

# %% [markdown]
# #### `spe`

# %%
validator.expect_column_values_to_be_of_type(column='spe', type_='VARCHAR')

# %% [markdown]
# #### `bst`

# %%
validator.expect_column_values_to_be_of_type(column='bst', type_='VARCHAR')

# %% [markdown]
# #### `mean`

# %%
validator.expect_column_values_to_be_of_type(column='mean', type_='VARCHAR')

# %% [markdown]
# #### `standard deviation`

# %%
validator.expect_column_values_to_be_of_type(column='standard deviation', type_='VARCHAR')

# %% [markdown]
# #### `generation`

# %%
validator.expect_column_values_to_be_of_type(column='generation', type_='VARCHAR')

# %% [markdown]
# #### `experience type`

# %%
validator.expect_column_values_to_be_of_type(column='experience type', type_='VARCHAR')

# %% [markdown]
# #### `experience to level 100`

# %%
validator.expect_column_values_to_be_of_type(column='experience to level 100', type_='VARCHAR')

# %% [markdown]
# #### `final evolution`

# %%
validator.expect_column_values_to_be_of_type(column='final evolution', type_='VARCHAR')

# %% [markdown]
# #### `catch rate`

# %%
validator.expect_column_values_to_be_of_type(column='catch rate', type_='VARCHAR')

# %% [markdown]
# #### `legendary`

# %%
validator.expect_column_values_to_be_of_type(column='legendary', type_='VARCHAR')

# %% [markdown]
# #### `mega evolution`

# %%
validator.expect_column_values_to_be_of_type(column='mega evolution', type_='VARCHAR')

# %% [markdown]
# #### `alolan form`

# %%
validator.expect_column_values_to_be_of_type(column='alolan form', type_='VARCHAR')

# %% [markdown]
# #### `galarian form`

# %%
validator.expect_column_values_to_be_of_type(column='galarian form', type_='VARCHAR')

# %% [markdown]
# #### `against normal`

# %%
validator.expect_column_values_to_be_of_type(column='against normal', type_='VARCHAR')

# %% [markdown]
# #### `against fire`

# %%
validator.expect_column_values_to_be_of_type(column='against fire', type_='VARCHAR')

# %% [markdown]
# #### `against water`

# %%
validator.expect_column_values_to_be_of_type(column='against water', type_='VARCHAR')

# %% [markdown]
# #### `against electric`

# %%
validator.expect_column_values_to_be_of_type(column='against electric', type_='VARCHAR')

# %% [markdown]
# #### `against grass`

# %%
validator.expect_column_values_to_be_of_type(column='against grass', type_='VARCHAR')

# %% [markdown]
# #### `against ice`

# %%
validator.expect_column_values_to_be_of_type(column='against ice', type_='VARCHAR')

# %% [markdown]
# #### `against fighting`

# %%
validator.expect_column_values_to_be_of_type(column='against fighting', type_='VARCHAR')

# %% [markdown]
# #### `against poison`

# %%
validator.expect_column_values_to_be_of_type(column='against poison', type_='VARCHAR')

# %% [markdown]
# #### `against ground`

# %%
validator.expect_column_values_to_be_of_type(column='against ground', type_='VARCHAR')

# %% [markdown]
# #### `against flying`

# %%
validator.expect_column_values_to_be_of_type(column='against flying', type_='VARCHAR')

# %% [markdown]
# #### `against psychic`

# %%
validator.expect_column_values_to_be_of_type(column='against psychic', type_='VARCHAR')

# %% [markdown]
# #### `against bug`

# %%
validator.expect_column_values_to_be_of_type(column='against bug', type_='VARCHAR')

# %% [markdown]
# #### `against rock`

# %%
validator.expect_column_values_to_be_of_type(column='against rock', type_='VARCHAR')

# %% [markdown]
# #### `against ghost`

# %%
validator.expect_column_values_to_be_of_type(column='against ghost', type_='VARCHAR')

# %% [markdown]
# #### `against dragon`

# %%
validator.expect_column_values_to_be_of_type(column='against dragon', type_='VARCHAR')

# %% [markdown]
# #### `against dark`

# %%
validator.expect_column_values_to_be_of_type(column='against dark', type_='VARCHAR')

# %% [markdown]
# #### `against steel`

# %%
validator.expect_column_values_to_be_of_type(column='against steel', type_='VARCHAR')

# %% [markdown]
# #### `against fairy`

# %%
validator.expect_column_values_to_be_of_type(column='against fairy', type_='VARCHAR')

# %% [markdown]
# #### `height`

# %%
validator.expect_column_values_to_be_of_type(column='height', type_='VARCHAR')

# %% [markdown]
# #### `weight`

# %%
validator.expect_column_values_to_be_of_type(column='weight', type_='VARCHAR')

# %% [markdown]
# #### `bmi`

# %%
validator.expect_column_values_to_be_of_type(column='bmi', type_='VARCHAR')

# %% [markdown]
# ## Review & Save Your Expectations
#
# Let's save the expectation suite as a JSON file in the `great_expectations/expectations` directory of your project.
#
# Let's now rebuild your Data Docs, which helps you communicate about your data with both machines and humans.

# %%
print(validator.get_expectation_suite(discard_failed_expectations=False))
validator.save_expectation_suite(discard_failed_expectations=False)

checkpoint_config = {
    "class_name": "SimpleCheckpoint",
    "validations": [
        {
            "batch_request": batch_request,
            "expectation_suite_name": expectation_suite_name
        }
    ]
}
checkpoint = SimpleCheckpoint(
    f"_tmp_checkpoint_{expectation_suite_name}",
    context,
    **checkpoint_config
)
checkpoint_result = checkpoint.run()

context.build_data_docs()

validation_result_identifier = checkpoint_result.list_validation_result_identifiers()[0]
context.open_data_docs(resource_identifier=validation_result_identifier)
